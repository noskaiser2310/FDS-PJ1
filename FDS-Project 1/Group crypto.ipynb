# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import plotly.express as px
from scipy.signal import argrelextrema

# %%
from read_data import read_datas
read_datas('Group cryto.csv')

# %%
df.head(10)
# Out:
#             Bitcoin_Price  Bitcoin_Vol.  Ethereum_Price  Ethereum_Vol.  \
# Date
# 2019-02-04         3462.8      503920.0          107.90      5020000.0
# 2019-02-05         3468.4      460950.0          107.37      4670000.0
# 2019-02-06         3404.3      514210.0          104.63      6150000.0
# 2019-02-07         3397.7      471360.0          104.55      5050000.0
# 2019-02-08         3661.7      699230.0          119.23      9190000.0
# 2019-02-11         3631.8      517280.0          121.30      6130000.0
# 2019-02-12         3632.0      545820.0          122.64      5740000.0
# 2019-02-13         3611.5      558020.0          122.22      6170000.0
# 2019-02-14         3592.6      498140.0          120.97      5810000.0
# 2019-02-15         3604.7      516210.0          121.73      5690000.0
#
#             Gold_Price  Gold_Vol.
# Date
# 2019-02-04      1319.3   159560.0
# 2019-02-05      1319.2   129010.0
# 2019-02-06      1314.4   137250.0
# 2019-02-07      1314.2   166760.0
# 2019-02-08      1318.5   150610.0
# 2019-02-11      1311.9   150610.0
# 2019-02-12      1314.0   146450.0
# 2019-02-13      1315.1   213960.0
# 2019-02-14      1313.9   228460.0
# 2019-02-15      1322.1   200280.0

# %%
from Weekly_price import weekly_price

# %%
weekly_price('Bitcoin_Price')

# %%
weekly_price('Ethereum_Price')
